# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.predict(
    source=["cat.jpg", "cat1.jpg", "sunset.jfif", "sunset1.jpg"],
    save=True
)
# Out:
# 0: 640x640 1 cat, 266.6ms
# 1: 640x640 1 cat, 266.6ms
# 2: 640x640 (no detections), 266.6ms
# 3: 640x640 4 persons, 266.6ms
# Speed: 8.1ms preprocess, 266.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\Localws\runs\detect\predict-3

# %%
for result in results:
    print(f"\nImage: {result.path}")

    for box in result.boxes:
        class_id = int(box.cls[0])
        confidence = float(box.conf[0])
        label = model.names[class_id]
        bbox = box.xyxy[0].tolist()

        print(f"Object: {label}")
        print(f"Confidence Score: {confidence:.2f}")
        print(f"Bounding Box: {bbox}")
        print("-" * 30)
# Out:
# Image: image0.jpg
# Object: cat
# Confidence Score: 0.86
# Bounding Box: [270.1946716308594, 660.1357421875, 2664.1748046875, 5411.4267578125]
# ------------------------------
#
# Image: image1.jpg
# Object: cat
# Confidence Score: 0.87
# Bounding Box: [2.9188392162323, 0.0, 588.1783447265625, 326.5744323730469]
# ------------------------------
#
# Image: image2.jpg
#
# Image: image3.jpg
# Object: person
# Confidence Score: 0.45
# Bounding Box: [1247.5523681640625, 1431.848388671875, 1302.791015625, 1537.7205810546875]
# ------------------------------
# Object: person
# Confidence Score: 0.42
# Bounding Box: [580.6192016601562, 2026.5836181640625, 658.6741333007812, 2162.77197265625]
# ------------------------------
# Object: person
# Confidence Score: 0.39
# Bounding Box: [1667.4261474609375, 1430.30078125, 1717.1817626953125, 1531.3651123046875]
# ------------------------------
# Object: person
# Confidence Score: 0.37
# Bounding Box: [1914.433837890625, 1420.7410888671875, 2023.80126953125, 1526.6708984375]
# ------------------------------
