# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.predict(
    source="cat.jpg",
    save=True
)
# Out:
# image 1/1 C:\Users\Localws\cat.jpg: 640x384 1 cat, 293.5ms
# Speed: 15.2ms preprocess, 293.5ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to C:\Users\Localws\runs\detect\predict

# %%
results = model.predict(
    source=["cat.jpg", "cat1.jpg", "sunset.jfif", "sunset1.jpg"],
    save=True
)
# Out:
# 0: 640x640 1 cat, 282.7ms
# 1: 640x640 1 cat, 282.7ms
# 2: 640x640 (no detections), 282.7ms
# 3: 640x640 4 persons, 282.7ms
# Speed: 8.3ms preprocess, 282.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\Localws\runs\detect\predict
