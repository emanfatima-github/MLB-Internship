# %%
import os
import cv2
import easyocr
import matplotlib.pyplot as plt

# %%
reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# C:\Users\Localws\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\ao\nn\quantized\dynamic\modules\rnn.py:162: UserWarning: torch.quantize_per_tensor, torch.quantize_per_channel and other quantized tensor creation functions that produce tensors with dtype torch.quint8, torch.qint8, and torch.qint32 are deprecated and will be removed in a future PyTorch release. Please see https://github.com/pytorch/pytorch/issues/184982 for more information. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\aten\src\ATen\quantized\Quantizer.cpp:116.)
#   w_ih = torch.quantize_per_tensor(

# %%
def preprocess_image(image_path):
    image = cv2.imread(image_path)

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    threshold = cv2.threshold(
        gray,
        150,
        255,
        cv2.THRESH_BINARY
    )[1]
    return image, threshold

# %%
def extract_text(image_path):
    original, processed = preprocess_image(image_path)

    results = reader.readtext(processed)

    extracted_text = ""

    for result in results:
        extracted_text += result[1] + "\n"
    return original, extracted_text

# %%
def display_result(image_path):
    image, text = extract_text(image_path)

    plt.figure(figsize=(8,8))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()

    print("Extracted Text:\n")
    print(text)
    return text

# %%
def save_text(text, image_path):
    os.makedirs("output", exist_ok=True)

    filename = os.path.splitext(os.path.basename(image_path))[0]

    output_path = os.path.join("output", filename + ".txt")

    with open(output_path, "w", encoding="utf-8") as file:
        file.write(text)

    print(f"Saved: {output_path}")

# %%
image_path = "images/doc1.jpg"

text = display_result(image_path)

save_text(text, image_path)
# Out:
# C:\Users\Localws\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Extracted Text:
#
# Ovak)
# IVIULLLLIKU)
# Uolu
# WVOdo
# L
# Loio
# W)
# Jewe)
# 86
# Couanos
# Oodd soro
# )ms.
# Oh, d let us go in a caravan "
# Mrs. Russell shook her head.
# 66
# I know it sounds lovely, darling; but
# ;
# we to
# a caravan ?
# It would cost at least fifty pounds to buy onc,
# en if we had one;
# Daddy couldn't get away this summer:
# We
# ke up our minds to do without a
# holiday this year; but Ill tell you wha
# I1 do: well all
# go to Southend for the
# as
# we did last year, and
# r lunch and tea with us and have a
# splendid picnic:"
# 9)
# {6
# Then we can bathe again; ' said
# but; oh! I do wish I could ha
# ny and ride;
# 99
# he added unexpectedly.
# 66
# You don't know how I long
# ny,
# 9 )
# he continued, Sighing deeply
# as
# he remembered
# the blissful holi
# len a friend let him share his little Dartmoor pony and ride occasionall
# S6
# Southend is
# nothing but houses and people;
# 99
# cried Phyllis;
# 66
# its no b
# an this place; and oh! Mummie,
# I
# do
# SO
# long for fields
# and flowers
# imals;
# 9)
# she added piteously; and she shook
# her
# brown hair forv
# hide the tears in her eyes:
# 66
# 9)
# Never   mind, darling,
# you  shall
# have
# them
# one
# answered
# Jssell with easy vagueness.
# This really was not very comforting, and it was the most fortunate
# t at that moment a
# car
# stopped at the door:
# 66
# Uncle Edward!
# 9)
# shouted Bob, rushing from the room:
# Phyllis bru
# e tears SO
# hastily from her eyes that she arrived at the front door almo
# on as he did, and both
# flung themselves on the tall, kindly-looking man st
# g beside the car.
# (6
# Uncle Edward!
# Uncle
# Edward ! "
# they cried:
# 66
# You ve
# come
# at
# e've been longing to see you:
# Oh, how glad we are you re here ! "
# Now the delightful thing was that their uncle seemed just as pleased tc
# em
# as
# were to see him, and returned their hugs and greetings witH
# most
# cordiality:
# They
# were just   on
# the
# of dragging him into
# use, hanging one on each arm; when he said:
# 66
# not s0 fast.
# Ther
# 9 )
# me
# things to fetch in from the car:
# So saying he began diving into the back of it and bringing out, not OF
# itcase, but various parcels, which he handed out ne by oe:
# 66
# Mra+)0
# +LetircfcLicrenc Tsge brouchtfor
# vour motber
# 9)
# c1 L
# ,
# get
# No,
# day,
# Bob;
# long
# day;
# thing
# they
# point
# Stop,
#
# Saved: output\doc1.txt

# %%
image_folder = "images"

for file in os.listdir(image_folder):

    if file.lower().endswith((".jpg", ".jpeg", ".png")):

        image_path = os.path.join(image_folder, file)

        print("=" * 60)
        print("Image:", file)

        text = display_result(image_path)

        save_text(text, image_path)
# Out:
# ============================================================
# Image: book.jpg
# Extracted Text:
#
# a
# Of
# his belly
# also
# tc)
# at
# thinking
# tc)
# the
# he
# tc)
# the
# if the bear
# he
# in his
# wondering_
# 'v
# in the berries
# the
# being
# he went
# he
# or his
# to
# down,
# in ;
# hh
# as he
# aS
# evening
# from his face
# it t()
# JS
# the
# che sticky berry
# night:
# in
# for the
# to
# 6
# to
# that the bear did
# as
# ro che
# in his
# thoughts and
# the
# in" the
# he
# it
# hatchet out of
# he
# he
# the
# to
# the
# the handle, as the
# head, his hand on
# the
# in
# it by his
# 35
# he slept:
# belt
# him
# 0
# his
# up
# day
# he
# (e
# 2
# 04
# it to
# of
# be St
# 1;
# 3
# bit
# the
# raspberry
# morning,
# patch
# sqjuirrel
# although
# and
# nearly
# rustledl
# continuedl
# with
# jumpedl
# somne
# Ahwout
# great
# and
# full
# pine
# (ut
# the
# 1
# no)n-
# caution,
# elouds
# gone,
# needles
# his
# started
# hvegan
# -the
# skin.
# stiffness
# 4
# SUI)
# 6
# not
# hack
# the
# was
# rain
# was
# crash
# thicken
# S(ne,
# mouth:
# ^
# 1
# ancl
# the
# JI _
# alinost
# raspherries
# since
# "(
# shelter.
# was
# took
# and
# slnn -
# time
# Brian
# astt'
# jaeket,
# look
# straight_
# first
# life.
# 0ml
# He
# what
# another
# andd
# own
# had
# find
# had
# rolledl
#  dark_
# For
# came
# He
# ,hadl=
# 'himself;
# eaten
# 1
# mayhe
# surprised _
# madle
# afternoon,
# juice
# picked
# opened
# pouch.
# probahly =
# 1
# another
# and
# #s_
# washed
# the
# outside
# 6
# Later _
# the
# prepare
# shelter
# 4
# three
# and
# back
# rain
# was
# lake
# went
# understood
# drenched
# 4
# the
# roaredl
# just
# poundk
# and
# then
# lake:
# accepted
# 'hands;
# down
# put
# much
# had
# But
# still
# andd
# and _
# insicle
# was
# clouds
# there
# While =
# picked
# him,
# cherries
# took
# sheets.
# hurt
# shelter
# herries
# were
# 9
# want
# was
# but
# into
# through
# Soon
# rivulets ~
# came
# dry
# hack
# not _
# noticed
# darkness
# and
# cherries
# 1
# put _
# the
# jacket;
# that
# snug:
# and
# and
# sorted
# with
# the
# and
# Fhey
# He
# own
# apparently
# cavght
# raspberries
# 0
# weight;
# pile
# were
# with=
# When
# much
# were
# heing
# were
# saW
# softer
# held
# stream
# 1
# crushed
# than
# the
# jacket
# red
#
# Saved: output\book.txt
# ============================================================
# Image: doc1.jpg
# Extracted Text:
#
# Ovak)
# IVIULLLLIKU)
# Uolu
# WVOdo
# L
# Loio
# W)
# Jewe)
# 86
# Couanos
# Oodd soro
# )ms.
# Oh, d let us go in a caravan "
# Mrs. Russell shook her head.
# 66
# I know it sounds lovely, darling; but
# ;
# we to
# a caravan ?
# It would cost at least fifty pounds to buy onc,
# en if we had one;
# Daddy couldn't get away this summer:
# We
# ke up our minds to do without a
# holiday this year; but Ill tell you wha
# I1 do: well all
# go to Southend for the
# as
# we did last year, and
# r lunch and tea with us and have a
# splendid picnic:"
# 9)
# {6
# Then we can bathe again; ' said
# but; oh! I do wish I could ha
# ny and ride;
# 99
# he added unexpectedly.
# 66
# You don't know how I long
# ny,
# 9 )
# he continued, Sighing deeply
# as
# he remembered
# the blissful holi
# len a friend let him share his little Dartmoor pony and ride occasionall
# S6
# Southend is
# nothing but houses and people;
# 99
# cried Phyllis;
# 66
# its no b
# an this place; and oh! Mummie,
# I
# do
# SO
# long for fields
# and flowers
# imals;
# 9)
# she added piteously; and she shook
# her
# brown hair forv
# hide the tears in her eyes:
# 66
# 9)
# Never   mind, darling,
# you  shall
# have
# them
# one
# answered
# Jssell with easy vagueness.
# This really was not very comforting, and it was the most fortunate
# t at that moment a
# car
# stopped at the door:
# 66
# Uncle Edward!
# 9)
# shouted Bob, rushing from the room:
# Phyllis bru
# e tears SO
# hastily from her eyes that she arrived at the front door almo
# on as he did, and both
# flung themselves on the tall, kindly-looking man st
# g beside the car.
# (6
# Uncle Edward!
# Uncle
# Edward ! "
# they cried:
# 66
# You ve
# come
# at
# e've been longing to see you:
# Oh, how glad we are you re here ! "
# Now the delightful thing was that their uncle seemed just as pleased tc
# em
# as
# were to see him, and returned their hugs and greetings witH
# most
# cordiality:
# They
# were just   on
# the
# of dragging him into
# use, hanging one on each arm; when he said:
# 66
# not s0 fast.
# Ther
# 9 )
# me
# things to fetch in from the car:
# So saying he began diving into the back of it and bringing out, not OF
# itcase, but various parcels, which he handed out ne by oe:
# 66
# Mra+)0
# +LetircfcLicrenc Tsge brouchtfor
# vour motber
# 9)
# c1 L
# ,
# get
# No,
# day,
# Bob;
# long
# day;
# thing
# they
# point
# Stop,
#
# Saved: output\doc1.txt
# ============================================================
# Image: doc10.jpg
# Extracted Text:
#
# Le c
# Bhuu
# sacted
# Inhb
# garmentre*
# ing in
# community
# 3
# hls €ce
# 21
# and
# 0
# heart moved:
# Offering to the LoRR'
# 6
# meeting forallteert
# iS
# p
# 22ANl
# alike, came
# T
# for
# kinds: brogohten
# willingz
# They
# allp
# offering to the
# T he
# he
# asa
# or scatt
# bayehaRuram skina
# d
# 23
# offering
# go8ght,e<
# offering to therta
# it
# wood for
# 25 Every skilled Woty
# d
# it:
# brought wtate
# scarkt yam
# who Wer
# hatr: DTL"
# do:
# other Gear
# breastploo
# 63
# h
# Ft
# 4
# 6rtwb
# mon edwol
# cnthhe
# Dilkc Ciic}
# tberacie
# gara
# the
# the
# woven
# both
# te
# "the
# said
# sanctuary
# Stdlont
# the
# DOpes;
# and
# than
# priest
# the
# priests:
# owhen
# mand
# the
# as
# serve
# Aaron
# Israelite
# they
# GTl
# for
# whole
# when
# eveld er
# near
# presence,
# sons
# the
# wOrd
# ome
# 20Then
# U
# Moses
# and
# whose
# 0
# Dron
# and
# from
# to
# sanctua
# to
# back
# willing_
# drew
# an
# was
# brought
# all
# wards
# who
# of
# and
# tent
# from
# garments:
# Yle
# them
# the
# Wa
# came
# sacred
# @ve
# on
# work
# had
# the
# women
# O
# on
# him
# the
# and
# and
# men
# all
# of
# The4
# vice,
# jewellery
# he
# ornaments:
# were
# 'All
# gold
# them,
# and
# port
# brought
# en-
# rings
# wave
# me
# purple
# earrings;
# gold
# Lhim,
# ers
# their_
# had
# finel
# sented
# 6y
# when
# who
# goat
# Everyone
# or
# had
# thetk
# leather
# linen,
# sam;
# the
# fine
# durable
# hands}
# was
# or
# face
# yarn
# other
# an
# tweng
# back
# presenting
# or
# red
# 3il
# an
# as
# nthe
# the
# 24 Those
# ady
# brought
# acacia
# vith
# had
# who
# bronze
# did
# everyone
# brought
# med
# and
# and
# work
# hands
# the
# her
# of
# or
# purple
# dw
# with
# {relite
# blue,
# dnd
# spun
# women
# the
# spun
# are
# all
# 802t
# had
# zse
# 2And
# the
# DTW
# spun
# skill
# and
# linen:
# 0
# the
# stones
# had
# ayenth
# onyx
# and
# and
# brought
# ephod
# Best
# Oll
# the
# olh
# and
# ers
# on
# mounted
# splces
# 0b0
# and
# brought
# anointngoll_
# E8of
# ako
#
# Saved: output\doc10.txt
# ============================================================
# Image: doc11.jpg
# Extracted Text:
#
# HOW INNOVATION WORKS
# The chief way in which innovation changes our lives is
# by enabling people to work for each other: As Ihave argued
# before, the main theme of human history is that we become
# steadily more
# specialized in what we produce, and steadily
# more diversified in what we consume: we move away from
# precarious self-sufficiency to safer mutual interdependence.
# By concentrating 0n serving other
# needs for
# hours a
# week
# which
# we call a job
# ~
# YOU
# can
# the
# other seventy-two
# hours (not counting fifty-six hours in
# bed) drawing upon the services provided to you by other
# people. Innovation has made it possible to work for a frac-
# tion of a second so as to be able to afford to
# turn
# on an
# electric lamp for an houg providing the quantity of light
# that would have
# required
# a
# whole days work if you had
# to make it yourself by collecting and refining sesame oil or
# lamb fat to burn in a simple
# as much of humanity did
# in the not so distant past;
# Most   innovation
# is
# a
# gradual  process:
# The
# modern
# obsession with disruptive innovation, a phrase coined by
# the Harvard professor Clayton Christensen in 1995,is mis-
# leading: Even when
# a
# new
# technology does upend an old
# one,
# as digital media
# has done
# to newspapers, the effect
# begins very slowly gathers pace gradually and works by
# increments, not
# and bounds; Innovation often
# dis -
# appoints in its early years, only to exceed expectations once
# peoples
# forty
# spend
# lamp,
# leaps
#
# Saved: output\doc11.txt
# ============================================================
# Image: doc12.jpg
# Extracted Text:
#
# Oon
# tia
# _35
# the
# #They
# 2
# in
# 0
# jt
# finely
# they
# them
# Mor
# ates:
# tering  as
# docly
# 27For
# Athe
# fne linen
# Mnen;
# 4
# ban
# made
# fnely
# L
# 4
# as the LorD
# #they
# Dutedpur
# O
# 67
# Hon
# 0
# V
# 4
# Laorole
# Tnott
# Lo?
# On
# the LORD comn
# Dbreasttplaor
# e
# ephod
# Caicdcs
# tha
# On
# el
#
# Tobe
# prteotby/
# roban
# ofa
# other
# theworky
# tt
# mac
# ofthe
# aond
# Or
# cloth
# Cn
# cente
# AThe
# ofblue
# band
# the
# sar
# Janda
# opening
# teat:
# and
# O
# ingofacollar;
# As`
# not
# bam
# Se
# would
# purple
# goldand
# the
# ~ct
# that
# round
# blue;
# Nan
# S0
# OF
# ofpure
# egranates
# the
# lnen
# Obii
# twisted
# between
# bells
# pomegranates
# bewor{l
# made
# hem
# Ortindnte
# 25And
# the
# around
# and
# G
# robeto
# madeon
# bells
# commanded
# Z6The
# ofthe
# hem
# they
# Vt
# the
# round
# LORD
# his sons;
# the
# work ofaweaver
# and
# cpaand
# Aaron
# Iinen
# the
# Hnen:
# the.
# bluo
# twlsted
# end
# 'offine
# Itnen
# embn
# offnel
# twlsted
# work Ofem
# Barents;
# Of
# Moses:
# the
# commanded
# yar
# scarlet
# tho
# Ooteue
# and
# pbate,
# the
# made
# enz
# and
# Jon
# Bold
# Moly
# seak:
# on
# On
# Nee
# Sa
# ~otnd
# Aned
# stlold
# Da
#
# Saved: output\doc12.txt
# ============================================================
# Image: doc15.jpg
# Extracted Text:
#
# M
# 00
# Xo
# 0
# 8
# Framirg
# AT
# 3
# PVF_QE, TNF A~BIC
# J(UNC
# 10010
# 12/22/1
# aler
# alec
# Wi ne
# Qnline
# link
# SALE
# Yau
# with
# Stores
# availcble
# tom
# are
# SHIOPTNG
# Customer
# Policies
# FoR
# New!
# Valued
# TAN
# couPon
# 43
# leo
# 15.20
# 2
# 2
#
# Saved: output\doc15.txt
# ============================================================
# Image: doc3.jpg
# Extracted Text:
#
# Ovak)
# IVIULLLLIKU)
# Uolu
# WVOdo
# L
# Loio
# W)
# Jewe)
# 86
# Couanos
# Oodd soro
# )ms.
# Oh, d let us go in a caravan "
# Mrs. Russell shook her head.
# 66
# I know it sounds lovely, darling; but
# ;
# we to
# a caravan ?
# It would cost at least fifty pounds to buy onc,
# en if we had one;
# Daddy couldn't get away this summer:
# We
# ke up our minds to do without a
# holiday this year; but Ill tell you wha
# I1 do: well all
# go to Southend for the
# as
# we did last year, and
# r lunch and tea with us and have a
# splendid picnic:"
# 9)
# {6
# Then we can bathe again; ' said
# but; oh! I do wish I could ha
# ny and ride;
# 99
# he added unexpectedly.
# 66
# You don't know how I long
# ny,
# 9 )
# he continued, Sighing deeply
# as
# he remembered
# the blissful holi
# len a friend let him share his little Dartmoor pony and ride occasionall
# S6
# Southend is
# nothing but houses and people;
# 99
# cried Phyllis;
# 66
# its no b
# an this place; and oh! Mummie,
# I
# do
# SO
# long for fields
# and flowers
# imals;
# 9)
# she added piteously; and she shook
# her
# brown hair forv
# hide the tears in her eyes:
# 66
# 9)
# Never   mind, darling,
# you  shall
# have
# them
# one
# answered
# Jssell with easy vagueness.
# This really was not very comforting, and it was the most fortunate
# t at that moment a
# car
# stopped at the door:
# 66
# Uncle Edward!
# 9)
# shouted Bob, rushing from the room:
# Phyllis bru
# e tears SO
# hastily from her eyes that she arrived at the front door almo
# on as he did, and both
# flung themselves on the tall, kindly-looking man st
# g beside the car.
# (6
# Uncle Edward!
# Uncle
# Edward ! "
# they cried:
# 66
# You ve
# come
# at
# e've been longing to see you:
# Oh, how glad we are you re here ! "
# Now the delightful thing was that their uncle seemed just as pleased tc
# em
# as
# were to see him, and returned their hugs and greetings witH
# most
# cordiality:
# They
# were just   on
# the
# of dragging him into
# use, hanging one on each arm; when he said:
# 66
# not s0 fast.
# Ther
# 9 )
# me
# things to fetch in from the car:
# So saying he began diving into the back of it and bringing out, not OF
# itcase, but various parcels, which he handed out ne by oe:
# 66
# Mra+)0
# +LetircfcLicrenc Tsge brouchtfor
# vour motber
# 9)
# c1 L
# ,
# get
# No,
# day,
# Bob;
# long
# day;
# thing
# they
# point
# Stop,
#
# Saved: output\doc3.txt
# ============================================================
# Image: doc4.jpg
# Extracted Text:
#
# $
# <
# 4 {
# 0
# 1e7 4
# b~6
# 1
# S-
# <
# ;
# 2714:
# #~r
# 1
# K
# 1
# Y
# N
# 0
#
# Saved: output\doc4.txt
# ============================================================
# Image: doc6.jpg
# Extracted Text:
#
# Ana
# JN
# 3a15u55
# Dor
# Please
# Check
# EKTACHR MF
# EJe/w
# PRINt
# KOpAcOLoR
# DUPLICATE
# Loboru:a
# Se
# COLOR
# PRINT
# OTHER
# NAME
# CZuLeexen) TERRx
# TEL
# 212
# PLEASE
# PRINT
# UNIT
# 32
# Scses
# APO
# 96308
# INSTRUCTIONS
# WORK
# PERFORMED
# This Envelope Contains
# Processed
# Vnit Cost
# Extention
# Of
# ROLls
# SIZES
# NO.
# Of
# B/W
# FILM
# ROLLS
# EKTACHROME-X
# DUPES
# KODACOLOR -X
# l2sh2
# COPYING
# NEGATIVES
# 2R
# SLIDES
# Order Quarlity
# 6
# 3S
# 3R
# EACH:
# SIZE
# 2x
# VERIF
# TOTALS
# ASSORTED   SIZE
# Wyh
# CLERK
# S
# DEPOSIT
# SiGNA
# URE_
# rtEk
# BALANCE
# 111280
# 'ions
# I0
# RE
# RegitE:
#
# Saved: output\doc6.txt
# ============================================================
# Image: doc7.jpg
# Extracted Text:
#
# ~
# 8
# 3
# 0
# odt;
# 8
# 8
# N
# ~
# 8&
# 4
# :<
# :8
# 8
# ~
# ~
# 28
# 8
# :
# ~
# ~
# <
# N
# 72
# 24
# ~
# 8
# 4
# @
# ~
# 401
# 2
# 4
# =
# Kwh
# 3
# 1
# '{ / > :
# 1
# ~
# 3
# 8 $ 0
# 6
# 8 <
# {6
# 0
# '10
# 2
# 0
# 1
# 0
# IumlmL
# [
# 1
# 3
# 1
# 8
# 3
# Blttcrcoln Is an old calculator machinc hackcd
# uscd
# 95
# Idatlng thc pcnding bltcol
# transactlons In
# 22
# thc blockchain
# Blttercoln
# 'comblnes Intcrnct of ThIngs
# 34
# mede
# archacol
# and cconomics  It works
# Oe
# baslc computcr, Incrcaslng thc Hmt nCC
#  blrcoins to almost an eternity: Tho 0r
# dlsplayed
# calculator scrccn and
# For thc duratlon
# its exhlbltion perlc
# muce moncy Inslstently and usinb
# whally diffcrcnt Irom the tradltor
# cumulates around
# machln
# { calculation requlred, Js wcll
# @xpended in thc process, ofter
# and the calculator
# Itself. Bltte
# worklng tlmc expcn
# nnological devices
# mlner that connects to blc
# likely; In the cvent of sucr
# nonce would be scnt bai
# responding bltcolns of1
# Iclty
# Origlnally; ta calculk
# {s8-=
# 0 084
# 'I7,6w &nc;
# ArokgtWy
# Altcor
# famers
# track tnelr Aun
# tonomously In
# capacity Of Me
# 298
# eulvalen
# theworldks t
# 2
# 2016
# Spear
# onds Ca
# 8 6
# [c 5
# Lz0
# 10 #
# 0 (1.+ #9
# h +7 9
# 1.8
# 6 9 6 2,
# 0 L
# S5
# Sfuull'
# 9 5
# 6 $ (4
# 66
# 66
# p
# L
# 69
# 720.
# 6*"
# 61
# 3
# 1
# 8
# 1
# 7
# :
# 1
# {
# :
# ~piuastol
# JWnsuoj Nipinjaja
# TILr OLIt[
# 2
# dumiWu pinnalr}
# 2
# 1
# jo spuons F6T
# 1
# 1
# Vi0j1i8
# Hppop _
# ' Lt6sE 31
# snd 8uptu
# 0
# 8
# 1
# 1
# M
# sh
# ]
# 1 > '
#
# 1
# L
# 1
# Jesq
# 1
# 1
# 1
# 1
# |
# 1
# 1
# j
# 1
# mlncr wall
# (loT}
# 7
# [
# Bitte -
# '750i c
# 60z0*
# Mertin
# ,116
#
# Saved: output\doc7.txt
# ============================================================
# Image: doc9.jpg
# Extracted Text:
#
# Tee
# brne a
# It is t
# Mchote
# loas
# La
# oliveo4;
# 2
# erde
# 78
# is
# mixed Waty
# it
# Poura ee
# ohem
# 0
# zlf
# ofthe fine
# 0
# tobe
# grainolinn
# 'Bring
# Present It +
# to
# the altar eHesh
# it to
# from thegr
# 4
# 3 foodafc
# it
# Loro: sThen %
# to
# Anonondat
# to
# offernt ,
# 7ng
# offarl8e5n
# #
# 11
# "Every
# 2
# bopapn
# 7o
# Dyovm
# bwn
# 0d
# Ga
# M
# OD
# n
# ri6you
# conskt
# made
# Ovon;
# oaves
# thla
# thrck
# or
# 'mixed in
# with
# ott
# brushed
# Vld
# on
# prepared
# and
# pd
# four
# Zraldr
# fering
# finest
# and
# ~
# the
# SCrumble;
# Couov
# of
# grain
# your
# yeast
# Oaces
# made
# offering
# Dmon
# Pan
# itis
# the
# CThen
# Ban,
# oil
# Pr
# LORD;
# pieces,
# Olive-
# the
# {te
# adthat
# things
# take
# C
# shall
# portion
# Sin
# memorial
# #__
# as
# the
# altar
# Ond
# the
# on
# abumt
# bum
# the
# Pleasing
# to
# asing
# feringbelongs
# food
# ofthe
# part
# from
# hal
# gln-
# Teod
# Lordr
# wchout
# Liou
# made
# poust6e
# O5
# Meast
# aR
# #an dotnLORD
# 0feng
# mn
# 35
# Boe
# Toadt
# Droe
#
# Saved: output\doc9.txt
# ============================================================
# Image: handwritten.jpg
# Extracted Text:
#
# We
# have
# fadly
# made
# t
# declsion
# 1
# temporarily
# lose
# tese
# Officult
# mime $
# &
# hope
# #at
# # IS
# Rov
# Shovt
# hme
# e
# we
# Wili
# be
# back
# Doing
# What
# W2
# love
# most Suirrolinded
# by
# olv
# loyal
# Clstomer $ _
# Saf2
# ana
# In
# Tuch
# On
# Instzgam
# @ Salad,slsters
# Jodie
# Jacki
# 4
# #be
# entire
# Salaa
# Sisters
# family
# XoxoxoX
# ISTERS
# SOUp OF THE DAY
# DRINKS
# served
# with toast
# COFFEE
# aing
# amazig
# nealry
# Stay
# Stay
#
# Saved: output\handwritten.txt
# ============================================================
# Image: invoice.jpg
# Extracted Text:
#
# ~
# 8
# 3
# 0
# odt;
# 8
# 8
# N
# ~
# 8&
# 4
# :<
# :8
# 8
# ~
# ~
# 28
# 8
# :
# ~
# ~
# <
# N
# 72
# 24
# ~
# 8
# 4
# @
# ~
# 401
# 2
# 4
# =
# Kwh
# 3
# 1
# '{ / > :
# 1
# ~
# 3
# 8 $ 0
# 6
# 8 <
# {6
# 0
# '10
# 2
# 0
# 1
# 0
# IumlmL
# [
# 1
# 3
# 1
# 8
# 3
# Blttcrcoln Is an old calculator machinc hackcd
# uscd
# 95
# Idatlng thc pcnding bltcol
# transactlons In
# 22
# thc blockchain
# Blttercoln
# 'comblnes Intcrnct of ThIngs
# 34
# mede
# archacol
# and cconomics  It works
# Oe
# baslc computcr, Incrcaslng thc Hmt nCC
#  blrcoins to almost an eternity: Tho 0r
# dlsplayed
# calculator scrccn and
# For thc duratlon
# its exhlbltion perlc
# muce moncy Inslstently and usinb
# whally diffcrcnt Irom the tradltor
# cumulates around
# machln
# { calculation requlred, Js wcll
# @xpended in thc process, ofter
# and the calculator
# Itself. Bltte
# worklng tlmc expcn
# nnological devices
# mlner that connects to blc
# likely; In the cvent of sucr
# nonce would be scnt bai
# responding bltcolns of1
# Iclty
# Origlnally; ta calculk
# {s8-=
# 0 084
# 'I7,6w &nc;
# ArokgtWy
# Altcor
# famers
# track tnelr Aun
# tonomously In
# capacity Of Me
# 298
# eulvalen
# theworldks t
# 2
# 2016
# Spear
# onds Ca
# 8 6
# [c 5
# Lz0
# 10 #
# 0 (1.+ #9
# h +7 9
# 1.8
# 6 9 6 2,
# 0 L
# S5
# Sfuull'
# 9 5
# 6 $ (4
# 66
# 66
# p
# L
# 69
# 720.
# 6*"
# 61
# 3
# 1
# 8
# 1
# 7
# :
# 1
# {
# :
# ~piuastol
# JWnsuoj Nipinjaja
# TILr OLIt[
# 2
# dumiWu pinnalr}
# 2
# 1
# jo spuons F6T
# 1
# 1
# Vi0j1i8
# Hppop _
# ' Lt6sE 31
# snd 8uptu
# 0
# 8
# 1
# 1
# M
# sh
# ]
# 1 > '
#
# 1
# L
# 1
# Jesq
# 1
# 1
# 1
# 1
# |
# 1
# 1
# j
# 1
# mlncr wall
# (loT}
# 7
# [
# Bitte -
# '750i c
# 60z0*
# Mertin
# ,116
#
# Saved: output\invoice.txt
# ============================================================
# Image: receipt.jpg
# Extracted Text:
#
# Ana
# JN
# 3a15u55
# Dor
# Please
# Check
# EKTACHR MF
# EJe/w
# PRINt
# KOpAcOLoR
# DUPLICATE
# Loboru:a
# Se
# COLOR
# PRINT
# OTHER
# NAME
# CZuLeexen) TERRx
# TEL
# 212
# PLEASE
# PRINT
# UNIT
# 32
# Scses
# APO
# 96308
# INSTRUCTIONS
# WORK
# PERFORMED
# This Envelope Contains
# Processed
# Vnit Cost
# Extention
# Of
# ROLls
# SIZES
# NO.
# Of
# B/W
# FILM
# ROLLS
# EKTACHROME-X
# DUPES
# KODACOLOR -X
# l2sh2
# COPYING
# NEGATIVES
# 2R
# SLIDES
# Order Quarlity
# 6
# 3S
# 3R
# EACH:
# SIZE
# 2x
# VERIF
# TOTALS
# ASSORTED   SIZE
# Wyh
# CLERK
# S
# DEPOSIT
# SiGNA
# URE_
# rtEk
# BALANCE
# 111280
# 'ions
# I0
# RE
# RegitE:
#
# Saved: output\receipt.txt
# ============================================================
# Image: signboard.jpg
# Extracted Text:
#
# PASSING
# PLACE
#
# Saved: output\signboard.txt
