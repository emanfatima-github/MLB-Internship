# %%
import cv2
import os

# %%
os.makedirs("output", exist_ok=True)

print("Output folder created successfully.")
# Out:
# Output folder created successfully.

# %%
# Process All Three Videos

import cv2
import os

videos = [
    "_videos/video1.mp4",
    "_videos/video2.mp4",
    "_videos/video3.mp4"
]

for index, video_path in enumerate(videos, start=1):

    video = cv2.VideoCapture(video_path)

    if not video.isOpened():
        print(f"Cannot open {video_path}")
        continue

    fps = video.get(cv2.CAP_PROP_FPS)

    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))

    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))

    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    print("------------------------------------")
    print("Video:", video_path)
    print("FPS:", fps)
    print("Width:", width)
    print("Height:", height)
    print("Total Frames:", total_frames)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    output = cv2.VideoWriter(
        f"output/processed_video{index}.mp4",
        fourcc,
        fps,
        (width, height),
        False
    )

    while True:

        ret, frame = video.read()

        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        blur = cv2.GaussianBlur(gray, (5,5), 0)

        edges = cv2.Canny(blur,100,200)

        cv2.imshow("Original Video", frame)

        cv2.imshow("Processed Video", edges)

        output.write(edges)

        if cv2.waitKey(25) & 0xFF == ord('q'):
            break

    video.release()

    output.release()

    cv2.destroyAllWindows()

print("All videos processed successfully.")
# Out:
# ------------------------------------
# Video: _videos/video1.mp4
# FPS: 29.97002997002997
# Width: 2160
# Height: 3840
# Total Frames: 624
# ------------------------------------
# Video: _videos/video2.mp4
# FPS: 25.0
# Width: 2160
# Height: 4096
# Total Frames: 1296
# ------------------------------------
# Video: _videos/video3.mp4
# FPS: 59.94005994005994
# Width: 1920
# Height: 1080
# Total Frames: 1230
# All videos processed successfully.

# %%
import os

print(os.listdir("output"))
# Out:
# ['processed_video1.mp4', 'processed_video2.mp4', 'processed_video3.mp4']

# %%
# Webcam Test

import cv2

camera = cv2.VideoCapture(0)

while True:

    ret, frame = camera.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    blur = cv2.GaussianBlur(gray,(5,5),0)

    edges = cv2.Canny(blur,100,200)

    cv2.imshow("Original Webcam",frame)

    cv2.imshow("Processed Webcam",edges)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

camera.release()

cv2.destroyAllWindows()
